# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2 : import data
salary = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')
salary
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
x=salary['Experience Years'].values

# %%
y=salary['Salary'].values

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=7,random_state=2529)
print('train_set',x_train.shape,y_train.shape)
print('test_set',x_test.shape,y_test.shape)
# Out:
# train_set (33,) (7,)
# test_set (33,) (7,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
x_train=np.asanyarray(salary[['Experience Years']])
y_train=np.asanyarray(salary[['Salary']])
x_train = x_train.iloc[:len(y_train)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 5
#       3 x_train=np.asanyarray(salary[['Experience Years']])
#       4 y_train=np.asanyarray(salary[['Salary']])
# ----> 5 x_train = x_train.iloc[:len(y_train)]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [[9523.65050742]]

# %%
print(model.intercept_)
# Out:
# [25673.01576053]

# %%
salary.shape
# Out:
# (40, 2)

# %%
df=np.array([x_test])
X_test=df.reshape(-1,1)
pred=model.predict(X_test)
pred
# Out:
# array([[6.02091811e+08],
#        [5.43645168e+08],
#        [5.44673722e+08],
#        [4.07390300e+08],
#        [4.59694188e+08],
#        [8.57154219e+08],
#        [9.64790517e+08],
#        [1.04220827e+09],
#        [6.14301131e+08],
#        [4.14542561e+08],
#        [3.59362530e+08],
#        [5.62825800e+08],
#        [8.94677402e+08],
#        [4.40065945e+08],
#        [6.28862792e+08],
#        [1.00555174e+09],
#        [5.39464285e+08],
#        [1.16069201e+09],
#        [9.35943379e+08],
#        [6.13777330e+08],
#        [3.74714655e+08],
#        [5.18540825e+08],
#        [5.73349434e+08],
#        [3.79933615e+08],
#        [1.07272205e+09],
#        [7.91326746e+08],
#        [7.74898449e+08],
#        [6.47043441e+08],
#        [7.82869745e+08],
#        [5.72873251e+08],
#        [1.11399755e+09],
#        [5.31388229e+08],
#        [1.08393138e+09]])

# %%
#model accuracy
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
print(len(y_test))
# Out:
# 7

# %% [raw]
# print(len(pred))

# %%
mean_absolute_error(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 mean_absolute_error(y_test,pred)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
# ...

# %%
mean_absolute_percentage_error(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 mean_absolute_percentage_error(y_test,pred)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
# ...
