# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# data=pd.read_csv('placement.csv')
# data.head()

# %%
data.sample(5)
# Out:
#    cgpa  resume  places
# 0  8.14    6.52       1
# 1  6.17    5.17       0
# 2  8.27    8.86       1
# 4  7.52    7.30       1
# 3  6.88    7.27       1

# %%
x=data.drop('places',axis=1)

# %%
y=data['places']

# %%
#Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (4, 2)

# %%
x_test.shape
# Out:
# (1, 2)

# %%
y_train.shape
# Out:
# (4,)

# %%
y_test.shape
# Out:
# (1,)

# %%
#standarization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaler=scaler.transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
x_train.describe()
# Out:
#            cgpa    resume
# count  4.000000  4.000000
# mean   7.177500  6.565000
# std    0.846025  0.997547
# min    6.170000  5.170000
# 25%    6.702500  6.182500
# 50%    7.200000  6.895000
# 75%    7.675000  7.277500
# max    8.140000  7.300000

# %%
scaler.mean_
# Out:
# array([7.1775, 6.565 ])

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cgpa    4 non-null      float64
#  1   resume  4 non-null      float64
# dtypes: float64(2)
# memory usage: 96.0 bytes

# %%
x_train_scaler=pd.DataFrame(x_train_scaler,columns=x_train.columns)
x_test_scaler=pd.DataFrame(x_test_scaler,columns=x_test.columns)

# %%
x_train_scaler.head()
# Out:
#        cgpa    resume
# 0  1.313672 -0.052089
# 1 -1.375090 -1.614768
# 2 -0.406044  0.816066
# 3  0.467462  0.850792

# %%
x_train.head()
# Out:
#    cgpa  resume
# 0  8.14    6.52
# 1  6.17    5.17
# 3  6.88    7.27
# 4  7.52    7.30

# %%
np.round(x_train_scaler.describe())
# Out:
#        cgpa  resume
# count   4.0     4.0
# mean   -0.0    -0.0
# std     1.0     1.0
# min    -1.0    -2.0
# 25%    -1.0    -0.0
# 50%     0.0     0.0
# 75%     1.0     1.0
# max     1.0     1.0

# %%
#effect of scaling
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['cgpa'],x_train['resume'])
ax1.set_title('Before Scaling')
ax2.scatter(x_train_scaler['cgpa'],x_train_scaler['resume'],color='red')
ax2.set_title('after scaling')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr_scaled=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_scaled.fit(x_train_scaler,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_train)
y_pred
# Out:
# array([1, 0, 1, 1], dtype=int64)

# %%
x_test.head(
# Out:
#    cgpa  resume
# 2  8.27    8.86

# %%
y_pred_scales=lr_scaled.predict(x_test_scaler)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 y_pred_scales=lr_scaled.predict(x_test_scaler)
#
# File C:\python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:382, in LinearClassifierMixin.predict(self, X)
#     368 """
#     369 Predict class labels for samples in X.
#     370
#    (...)
#     379     Vector containing the class labels for each sample.
#     380 """
#     381 xp, _ = get_namespace(X)
# --> 382 scores = self.decision_function(X)
#     383 if len(scores.shape) == 1:
#     384     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File C:\python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:360, in LinearClassifierMixin.decision_function(self, X)
#     341 def decision_function(self, X):
#     342     """
#     343     Predict confidence scores for samples.
#     344
#    (...)
# ...
